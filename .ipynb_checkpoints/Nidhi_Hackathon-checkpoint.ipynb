# %%
import pandas as pd

# %%
forestfire_df=pd.read_csv('Amazon_Updated.csv',encoding='ISO-8859-1')

# %%
forestfire_df
# Out:
#       Year      State     Month  Forest_Fire
# 0     1998       Acre   January          0.0
# 1     1999       Acre   January          0.0
# 2     2000       Acre   January          0.0
# 3     2001       Acre   January          0.0
# 4     2002       Acre   January          0.0
# 5     2003       Acre   January         10.0
# 6     2004       Acre   January          0.0
# 7     2005       Acre   January         12.0
# 8     2006       Acre   January          4.0
# 9     2007       Acre   January          0.0
# 10    2008       Acre   January          0.0
# 11    2009       Acre   January          0.0
# 12    2010       Acre   January          1.0
# 13    2011       Acre   January          0.0
# 14    2012       Acre   January          0.0
# 15    2013       Acre   January          0.0
# 16    2014       Acre   January          0.0
# 17    2015       Acre   January          1.0
# 18    2016       Acre   January         12.0
# 19    2017       Acre   January          0.0
# ...

# %%
ls
# Out:
# Amazon_Updated.csv  Location.csv        Weather_Info/       firedata.csv
# DataCleaning.py     Untitled.ipynb      amazon.csv*

# %%
cd Weather_Info/
# Out:
# /Users/praveenkumar/amazonFires/Weather_Info

# %%
ls
# Out:
# Alagoas/  Amapa/    Amazonas/ Bahia/

# %%
import os

# %%
import glob

# %%
glob.glob('/Users/praveenkumar/amazonFires/Weather_Info/*')
# Out:
# ['/Users/praveenkumar/amazonFires/Weather_Info/Amazonas',
#  '/Users/praveenkumar/amazonFires/Weather_Info/Amapa',
#  '/Users/praveenkumar/amazonFires/Weather_Info/Alagoas',
#  '/Users/praveenkumar/amazonFires/Weather_Info/Bahia']

# %%
Amazonas=[]
Bahia=[]
Alagoas=[]
Amapa=[]
for file in glob.glob('/Users/praveenkumar/amazonFires/Weather_Info/*'):
    for files in glob.glob(file +'/*'):
        for values in glob.glob(files+"/*"):
           
            split=values.split('/')
            print(split[5])
            if split[5]=='Bahia':
                Bahia.append(values)
            elif split[5]=='Alagoas':
                Alagoas.append(values)
            elif split[5]=='Amapa':
                Amapa.append(values)
            elif split[5]=='Amazonas':
                Amazonas.append(values)
# Out:
# Amazonas
# Amazonas
# Amazonas
# Amazonas
# Amazonas
# Amazonas
# Amazonas
# Amazonas
# Amazonas
# Amazonas
# Amazonas
# Amazonas
# Amazonas
# Amazonas
# Amazonas
# Amazonas
# Amazonas
# Amazonas
# Amazonas
# Amazonas
# Amazonas
# Amazonas
# Amazonas
# Amazonas
# Amazonas
# Amazonas
# Amazonas
# Amazonas
# Amazonas
# Amazonas
# Amazonas
# Amazonas
# Amazonas
# Amazonas
# Amazonas
# Amazonas
# Amazonas
# Amazonas
# Amazonas
# Amazonas
# Amazonas
# Amazonas
# Amazonas
# Amazonas
# Amazonas
# Amazonas
# Amazonas
# Amazonas
# Amazonas
# Amazonas
# Amazonas
# Amazonas
# Amazonas
# Amazonas
# Amazonas
# Amazonas
# Amazonas
# Amazonas
# Amazonas
# Amazonas
# Amazonas
# Amazonas
# Amazonas
# Amazonas
# Amazonas
# Amazonas
# Amazonas
# Amazonas
# Amazonas
# Amazonas
# Amazonas
# Amazonas
# Amazonas
# Amazonas
# Amazonas
# Amazonas
# Amazonas
# Amazonas
# Amazonas
# Amazonas
# Amazonas
# Amazonas
# Amazonas
# Amazonas
# Amazonas
# Amazonas
# Amazonas
# Amazonas
# Amazonas
# Amazonas
# ...

# %%
len(Bahia)
# Out:
# 201

# %%
len(Amazonas)
# Out:
# 581

# %%
len(Amapa)
# Out:
# 56

# %%
len(Alagoas)
# Out:
# 60

# %%
test=Bahia[1]

# %%
test
# Out:
# '/Users/praveenkumar/amazonFires/Weather_Info/Bahia/12188_2019-09-07-12-51-22/weatherdata--123-422.csv'

# %%
testdata=pd.read_csv(test)

# %%
testdata
# Out:
#               Date  Longitude  Latitude  Elevation  Max Temperature  \
# 1/1/1979  -42.1875    -12.333      1076     28.893           15.199
